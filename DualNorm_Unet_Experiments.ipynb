# %% [markdown]
# <a href="https://colab.research.google.com/github/fentyjames/DualNorm_Unet_Experiment/blob/main/DualNorm_Unet_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the libraries
import torch, pdb
from torch.utils.data import DataLoader
from torch import nn
from torchvision import transforms
from torchvision.utils import make_grid
from tqdm.auto import tqdm #show beautiful progress bar
import matplotlib.pyplot as plt

import os
import random
from PIL import Image

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/UNET_ARCHITECTURE')
# Out:
# Mounted at /content/drive

# %%
import requests
from pathlib import Path


if Path("F_UNET_PARTS.py").is_file():
  print("F_UNET_PARTS.py already exists, skipping download")
else:
  print("DownloadingF_UNET_PARTS.py")
  # Get the file and read it
  request = requests.get("/content/drive/MyDrive/UNET_ARCHITECTURE/F_UNET_PARTS.py")
  with open("unet_parts8.py", "wb") as f:
    f.write(request.content)
# Out:
# F_UNET_PARTS.py already exists, skipping download

# %%
#%%writefile /content/drive/MyDrive/UNET_ARCHITECTURE/F_UNET_PARTS_V1.py
import torch
import torch.nn as nn
import torch.nn.functional as F


class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, n_classes, nonlinear='relu'):
        super(ResBlock, self).__init__()
        self.nonlinear_layer = nn.ReLU(inplace=True)
        self.norm_0 = nn.BatchNorm2d(out_channels)
        self.norm_1 = nn.BatchNorm2d(out_channels)
        self.conv_0 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.conv_1 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        residual = x
        x = self.conv_0(x)
        x = self.nonlinear_layer(x)
        x = self.norm_0(x)
        x = self.conv_1(x)
        x = self.nonlinear_layer(x)
        x = self.norm_1(x)
        x += residual
        return x


class InConv(nn.Module):
    def __init__(self, in_channels, out_channels, n_classes, block=ResBlock, batchsize=4, nonlinear='relu'):
        super(InConv, self).__init__()
        self.nonlinear_layer = nn.ReLU(inplace=True)
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1),
        )
        self.block = ResBlock(out_channels, out_channels, n_classes)

    def forward(self, x):
        x = self.conv(x)
        x = self.block(x)
        return x


class Down(nn.Module):
    def __init__(self, in_channels, out_channels, n_classes, block=ResBlock, batchsize=4, nonlinear='relu'):
        super(Down, self).__init__()
        self.nonlinear_layer = nn.ReLU(inplace=True)
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels, out_channels, kernel_size=2, padding=1)
        )
        self.block = ResBlock(out_channels, out_channels, n_classes)

    def forward(self, x):
        x = self.maxpool_conv(x)
        x = self.block(x)
        return x


class Mid(nn.Module):
    def __init__(self, in_channels, out_channels, n_classes, batchsize=4, nonlinear='relu'):
        super(Mid, self).__init__()
        self.block = ResBlock(in_channels, out_channels, n_classes)

    def forward(self, x):
        x = self.block(x)
        return x


class TransConv(nn.Module):
    def __init__(self, in_channels, batchsize=4, nonlinear='relu'):
        super(TransConv, self).__init__()
        self.nonlinear_layer = nn.ReLU(inplace=True)
        self.up = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        x = self.up(x)
        return x



class Up(nn.Module):
    """Upscaling then double conv"""
    def __init__(self, in_channels, out_channels, n_classes=2, bilinear=True, block=ResBlock, batchsize=4,
                 nonlinear='relu', ):
        super().__init__()
        self.nonlinear_layer = nn.ReLU(inplace=True)
        self.up = TransConv(in_channels, batchsize=batchsize, nonlinear=nonlinear, )
        self.conv = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
            )
        self.blockname = block
        self.block = block(out_channels, out_channels, n_classes=n_classes,
                               nonlinear=nonlinear, )

    def forward(self, x1, x2, seg=None):
        x1 = self.up(x1)
        #print("Print Up X1: ", x1.size())
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])

        x = torch.cat([x2, x1], dim=1)
        #print("The values of X111", x.size())
        x = self.conv(x)
        x = self.block(x)
        return x


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels, batchsize=4, nonlinear='relu'):
        super(OutConv, self).__init__()
        self.nonlinear_layer = nn.ReLU(inplace=True)
        self.conv = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, out_channels, kernel_size=1) #, stride=1
        )

    def forward(self, x):
        x = self.conv(x)
        return x

# %%
#%%writefile /content/drive/MyDrive/UNET_ARCHITECTURE/F23_DUALNORM_V1.py
import torch
import torch.nn as nn
from F_UNET_PARTS_V1 import ResBlock, InConv, Down, Mid, Up, TransConv, OutConv

try:
  import torchinfo
except:
  # !pip install torchinfo
  import torchinfo

from torchinfo import summary


class DualNorm_Unet(nn.Module):
    def __init__(self, n_channels, n_classes, nonlinear='relu'):
        super(DualNorm_Unet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes

        self.inc = InConv(n_channels, 32, n_classes=n_classes, block=ResBlock, nonlinear=nonlinear)
        self.down1 = Down(32, 64, n_classes=n_classes, block=ResBlock, nonlinear=nonlinear)
        self.down2 = Down(64, 128, n_classes=n_classes, block=ResBlock, nonlinear=nonlinear)
        self.down3 = Down(128, 256, n_classes=n_classes, block=ResBlock, nonlinear=nonlinear)
        self.down4 = Down(256, 512, n_classes=n_classes, block=ResBlock, nonlinear=nonlinear)
        self.mid = Mid(512, 512, n_classes=n_classes, nonlinear=nonlinear)
        self.up1 = Up(512, 256, n_classes=n_classes, block=ResBlock, nonlinear=nonlinear)
        self.up2 = Up(256, 128, n_classes=n_classes,  block=ResBlock, nonlinear=nonlinear)
        self.up3 = Up(128, 64, n_classes=n_classes,  block=ResBlock, nonlinear=nonlinear)
        self.up4 = Up(64, 32, n_classes=n_classes,  block=ResBlock, nonlinear=nonlinear)
        self.outc = OutConv(32, n_classes, nonlinear=nonlinear)
        self.outsig = nn.Sigmoid()

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5_1 = self.down4(x4)
        x = self.mid(x5_1)
        x = self.up1(x, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.outc(x)
        x = self.outsig(x)
        return x



model_0 = DualNorm_Unet(n_channels=3, n_classes=1, )  # Create an instance of the DualNorm_Unet class dropout_rate=0.0
summary(model_0,
        input_size=[(16, 3, 224, 224)],
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
        )
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# DualNorm_Unet (DualNorm_Unet)            [16, 3, 224, 224]    [16, 1, 224, 224]    --                   True
# ├─InConv (inc)                           [16, 3, 224, 224]    [16, 32, 224, 224]   --                   True
# │    └─Sequential (conv)                 [16, 3, 224, 224]    [16, 32, 224, 224]   --                   True
# │    │    └─Conv2d (0)                   [16, 3, 224, 224]    [16, 32, 224, 224]   128                  True
# │    └─ResBlock (block)                  [16, 32, 224, 224]   [16, 32, 224, 224]   --                   True
# │    │    └─Conv2d (conv_0)              [16, 32, 224, 224]   [16, 32, 224, 224]   9,248                True
# │    │    └─ReLU (nonlinear_layer)       [16, 32, 224, 224]   [16, 32, 224, 224]   --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 32, 224, 224]   [16, 32, 224, 224]   64                   True
# │    │    └─Conv2d (conv_1)              [16, 32, 224, 224]   [16, 32, 224, 224]   9,248                True
# │    │    └─ReLU (nonlinear_layer)       [16, 32, 224, 224]   [16, 32, 224, 224]   --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 32, 224, 224]   [16, 32, 224, 224]   64                   True
# ├─Down (down1)                           [16, 32, 224, 224]   [16, 64, 113, 113]   --                   True
# │    └─Sequential (maxpool_conv)         [16, 32, 224, 224]   [16, 64, 113, 113]   --                   True
# │    │    └─MaxPool2d (0)                [16, 32, 224, 224]   [16, 32, 112, 112]   --                   --
# │    │    └─Conv2d (1)                   [16, 32, 112, 112]   [16, 64, 113, 113]   8,256                True
# │    └─ResBlock (block)                  [16, 64, 113, 113]   [16, 64, 113, 113]   --                   True
# │    │    └─Conv2d (conv_0)              [16, 64, 113, 113]   [16, 64, 113, 113]   36,928               True
# │    │    └─ReLU (nonlinear_layer)       [16, 64, 113, 113]   [16, 64, 113, 113]   --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 64, 113, 113]   [16, 64, 113, 113]   128                  True
# │    │    └─Conv2d (conv_1)              [16, 64, 113, 113]   [16, 64, 113, 113]   36,928               True
# │    │    └─ReLU (nonlinear_layer)       [16, 64, 113, 113]   [16, 64, 113, 113]   --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 64, 113, 113]   [16, 64, 113, 113]   128                  True
# ├─Down (down2)                           [16, 64, 113, 113]   [16, 128, 57, 57]    --                   True
# │    └─Sequential (maxpool_conv)         [16, 64, 113, 113]   [16, 128, 57, 57]    --                   True
# │    │    └─MaxPool2d (0)                [16, 64, 113, 113]   [16, 64, 56, 56]     --                   --
# │    │    └─Conv2d (1)                   [16, 64, 56, 56]     [16, 128, 57, 57]    32,896               True
# │    └─ResBlock (block)                  [16, 128, 57, 57]    [16, 128, 57, 57]    --                   True
# │    │    └─Conv2d (conv_0)              [16, 128, 57, 57]    [16, 128, 57, 57]    147,584              True
# │    │    └─ReLU (nonlinear_layer)       [16, 128, 57, 57]    [16, 128, 57, 57]    --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 128, 57, 57]    [16, 128, 57, 57]    256                  True
# │    │    └─Conv2d (conv_1)              [16, 128, 57, 57]    [16, 128, 57, 57]    147,584              True
# │    │    └─ReLU (nonlinear_layer)       [16, 128, 57, 57]    [16, 128, 57, 57]    --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 128, 57, 57]    [16, 128, 57, 57]    256                  True
# ├─Down (down3)                           [16, 128, 57, 57]    [16, 256, 29, 29]    --                   True
# │    └─Sequential (maxpool_conv)         [16, 128, 57, 57]    [16, 256, 29, 29]    --                   True
# │    │    └─MaxPool2d (0)                [16, 128, 57, 57]    [16, 128, 28, 28]    --                   --
# │    │    └─Conv2d (1)                   [16, 128, 28, 28]    [16, 256, 29, 29]    131,328              True
# │    └─ResBlock (block)                  [16, 256, 29, 29]    [16, 256, 29, 29]    --                   True
# │    │    └─Conv2d (conv_0)              [16, 256, 29, 29]    [16, 256, 29, 29]    590,080              True
# │    │    └─ReLU (nonlinear_layer)       [16, 256, 29, 29]    [16, 256, 29, 29]    --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 256, 29, 29]    [16, 256, 29, 29]    512                  True
# │    │    └─Conv2d (conv_1)              [16, 256, 29, 29]    [16, 256, 29, 29]    590,080              True
# │    │    └─ReLU (nonlinear_layer)       [16, 256, 29, 29]    [16, 256, 29, 29]    --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 256, 29, 29]    [16, 256, 29, 29]    512                  True
# ├─Down (down4)                           [16, 256, 29, 29]    [16, 512, 15, 15]    --                   True
# │    └─Sequential (maxpool_conv)         [16, 256, 29, 29]    [16, 512, 15, 15]    --                   True
# │    │    └─MaxPool2d (0)                [16, 256, 29, 29]    [16, 256, 14, 14]    --                   --
# │    │    └─Conv2d (1)                   [16, 256, 14, 14]    [16, 512, 15, 15]    524,800              True
# │    └─ResBlock (block)                  [16, 512, 15, 15]    [16, 512, 15, 15]    --                   True
# │    │    └─Conv2d (conv_0)              [16, 512, 15, 15]    [16, 512, 15, 15]    2,359,808            True
# │    │    └─ReLU (nonlinear_layer)       [16, 512, 15, 15]    [16, 512, 15, 15]    --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 512, 15, 15]    [16, 512, 15, 15]    1,024                True
# │    │    └─Conv2d (conv_1)              [16, 512, 15, 15]    [16, 512, 15, 15]    2,359,808            True
# │    │    └─ReLU (nonlinear_layer)       [16, 512, 15, 15]    [16, 512, 15, 15]    --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 512, 15, 15]    [16, 512, 15, 15]    1,024                True
# ├─Mid (mid)                              [16, 512, 15, 15]    [16, 512, 15, 15]    --                   True
# │    └─ResBlock (block)                  [16, 512, 15, 15]    [16, 512, 15, 15]    --                   True
# │    │    └─Conv2d (conv_0)              [16, 512, 15, 15]    [16, 512, 15, 15]    2,359,808            True
# │    │    └─ReLU (nonlinear_layer)       [16, 512, 15, 15]    [16, 512, 15, 15]    --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 512, 15, 15]    [16, 512, 15, 15]    1,024                True
# │    │    └─Conv2d (conv_1)              [16, 512, 15, 15]    [16, 512, 15, 15]    2,359,808            True
# │    │    └─ReLU (nonlinear_layer)       [16, 512, 15, 15]    [16, 512, 15, 15]    --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 512, 15, 15]    [16, 512, 15, 15]    1,024                True
# ├─Up (up1)                               [16, 512, 15, 15]    [16, 256, 29, 29]    --                   True
# │    └─TransConv (up)                    [16, 512, 15, 15]    [16, 256, 30, 30]    --                   True
# │    │    └─Sequential (up)              [16, 512, 15, 15]    [16, 256, 30, 30]    1,180,928            True
# │    └─Sequential (conv)                 [16, 512, 29, 29]    [16, 256, 29, 29]    --                   True
# │    │    └─Conv2d (0)                   [16, 512, 29, 29]    [16, 256, 29, 29]    1,179,904            True
# │    └─ResBlock (block)                  [16, 256, 29, 29]    [16, 256, 29, 29]    --                   True
# │    │    └─Conv2d (conv_0)              [16, 256, 29, 29]    [16, 256, 29, 29]    590,080              True
# │    │    └─ReLU (nonlinear_layer)       [16, 256, 29, 29]    [16, 256, 29, 29]    --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 256, 29, 29]    [16, 256, 29, 29]    512                  True
# │    │    └─Conv2d (conv_1)              [16, 256, 29, 29]    [16, 256, 29, 29]    590,080              True
# │    │    └─ReLU (nonlinear_layer)       [16, 256, 29, 29]    [16, 256, 29, 29]    --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 256, 29, 29]    [16, 256, 29, 29]    512                  True
# ├─Up (up2)                               [16, 256, 29, 29]    [16, 128, 57, 57]    --                   True
# │    └─TransConv (up)                    [16, 256, 29, 29]    [16, 128, 58, 58]    --                   True
# │    │    └─Sequential (up)              [16, 256, 29, 29]    [16, 128, 58, 58]    295,552              True
# │    └─Sequential (conv)                 [16, 256, 57, 57]    [16, 128, 57, 57]    --                   True
# │    │    └─Conv2d (0)                   [16, 256, 57, 57]    [16, 128, 57, 57]    295,040              True
# │    └─ResBlock (block)                  [16, 128, 57, 57]    [16, 128, 57, 57]    --                   True
# │    │    └─Conv2d (conv_0)              [16, 128, 57, 57]    [16, 128, 57, 57]    147,584              True
# │    │    └─ReLU (nonlinear_layer)       [16, 128, 57, 57]    [16, 128, 57, 57]    --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 128, 57, 57]    [16, 128, 57, 57]    256                  True
# │    │    └─Conv2d (conv_1)              [16, 128, 57, 57]    [16, 128, 57, 57]    147,584              True
# │    │    └─ReLU (nonlinear_layer)       [16, 128, 57, 57]    [16, 128, 57, 57]    --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 128, 57, 57]    [16, 128, 57, 57]    256                  True
# ├─Up (up3)                               [16, 128, 57, 57]    [16, 64, 113, 113]   --                   True
# │    └─TransConv (up)                    [16, 128, 57, 57]    [16, 64, 114, 114]   --                   True
# │    │    └─Sequential (up)              [16, 128, 57, 57]    [16, 64, 114, 114]   74,048               True
# │    └─Sequential (conv)                 [16, 128, 113, 113]  [16, 64, 113, 113]   --                   True
# │    │    └─Conv2d (0)                   [16, 128, 113, 113]  [16, 64, 113, 113]   73,792               True
# │    └─ResBlock (block)                  [16, 64, 113, 113]   [16, 64, 113, 113]   --                   True
# │    │    └─Conv2d (conv_0)              [16, 64, 113, 113]   [16, 64, 113, 113]   36,928               True
# │    │    └─ReLU (nonlinear_layer)       [16, 64, 113, 113]   [16, 64, 113, 113]   --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 64, 113, 113]   [16, 64, 113, 113]   128                  True
# │    │    └─Conv2d (conv_1)              [16, 64, 113, 113]   [16, 64, 113, 113]   36,928               True
# │    │    └─ReLU (nonlinear_layer)       [16, 64, 113, 113]   [16, 64, 113, 113]   --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 64, 113, 113]   [16, 64, 113, 113]   128                  True
# ├─Up (up4)                               [16, 64, 113, 113]   [16, 32, 224, 224]   --                   True
# │    └─TransConv (up)                    [16, 64, 113, 113]   [16, 32, 226, 226]   --                   True
# │    │    └─Sequential (up)              [16, 64, 113, 113]   [16, 32, 226, 226]   18,592               True
# │    └─Sequential (conv)                 [16, 64, 224, 224]   [16, 32, 224, 224]   --                   True
# │    │    └─Conv2d (0)                   [16, 64, 224, 224]   [16, 32, 224, 224]   18,464               True
# │    └─ResBlock (block)                  [16, 32, 224, 224]   [16, 32, 224, 224]   --                   True
# │    │    └─Conv2d (conv_0)              [16, 32, 224, 224]   [16, 32, 224, 224]   9,248                True
# │    │    └─ReLU (nonlinear_layer)       [16, 32, 224, 224]   [16, 32, 224, 224]   --                   --
# │    │    └─BatchNorm2d (norm_0)         [16, 32, 224, 224]   [16, 32, 224, 224]   64                   True
# │    │    └─Conv2d (conv_1)              [16, 32, 224, 224]   [16, 32, 224, 224]   9,248                True
# │    │    └─ReLU (nonlinear_layer)       [16, 32, 224, 224]   [16, 32, 224, 224]   --                   --
# │    │    └─BatchNorm2d (norm_1)         [16, 32, 224, 224]   [16, 32, 224, 224]   64                   True
# ├─OutConv (outc)                         [16, 32, 224, 224]   [16, 1, 224, 224]    --                   True
# │    └─Sequential (conv)                 [16, 32, 224, 224]   [16, 1, 224, 224]    --                   True
# │    │    └─BatchNorm2d (0)              [16, 32, 224, 224]   [16, 32, 224, 224]   64                   True
# │    │    └─ReLU (1)                     [16, 32, 224, 224]   [16, 32, 224, 224]   --                   --
# │    │    └─Conv2d (2)                   [16, 32, 224, 224]   [16, 1, 224, 224]    33                   True
# ├─Sigmoid (outsig)                       [16, 1, 224, 224]    [16, 1, 224, 224]    --                   --
# ========================================================================================================================
# Total params: 16,416,353
# Trainable params: 16,416,353
# Non-trainable params: 0
# Total mult-adds (G): 287.91
# ========================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 4854.21
# Params size (MB): 65.67
# Estimated Total Size (MB): 4929.51
# ========================================================================================================================

# %%
import numpy as np
from F5_JACCARD import Jaccard
#from F23_DULANORM_UNET_V3 import DualNorm_Unet
from timeit import default_timer as timer



dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#dev = torch.device("cpu")
device = torch.device(dev)

# Start the timer
start_time = timer()

def train_model(n_epochs, trainloss, validationloss, accuracy, model, scheduler, lrFile, training_generator, optim, lim, trainFile, trainaccFile, trainepochFile, validation_generator, valFile, valaccFile, pathm, i, modeltype):
    training_losses = []
    for epoch in tqdm(range(n_epochs)):
        model.train()
        batch_losses = []
        jI = 0
        totalBatches = 0
        scheduler.step()
        print('Epoch:', epoch,'LR:', scheduler.get_last_lr()) # Used .get_last_lr() instead of .get_lr()
        lrFile.write('Epoch:'+' '+str(epoch)+' '+'LR:'+' '+str(scheduler.get_last_lr())+"\n")
        lrFile.write(str(scheduler.state_dict())+"\n")

        mb=0
        for trainim, trainmas in training_generator:
            mb+=1
            optim.zero_grad()
            images=trainim.to(device)
            masks=trainmas.to(device)
            outputs=model(images)

            if trainloss =='BCEWithLogitsLoss':
                loss=nn.BCEWithLogitsLoss() #loss = nn.BCELoss()
                output = loss(outputs, masks)
            output.backward()
            optim.step()

            batch_losses.append(output.item())
            batchLoad = len(masks)*lim*lim
            totalBatches = totalBatches + batchLoad
            if accuracy == 'Jaccard':
                thisJac = Jaccard(torch.reshape(masks,(batchLoad,1)),torch.reshape(outputs,(batchLoad,1)))*batchLoad
                jI = jI+thisJac.data[0]

        training_loss = np.mean(batch_losses)
        training_losses.append(training_loss)
        trainFile.write(str(training_losses[epoch])+"\n")
        trainaccFile.write(str((jI/totalBatches).item())+"\n")
        trainepochFile.write(str(epoch)+"\n")


        # End the timer and print out how long it took
        end_time = timer()
        global total_train_time
        total_train_time = end_time - start_time
        print(f"Total training time: {end_time-start_time:.2f} seconds")
        print("=================================================================================")
        print("Training Jaccard:",(jI/totalBatches).item()," (epoch:",epoch,")","Training Locess: ",(training_losses[epoch]))
        print("---------------------------------------------------------------------------------\n")
        lrFile.write("Training loss:"+str(training_losses[epoch])+"\n")
        lrFile.write("Training accuracy:"+str((jI/totalBatches).item())+"\n")


        torch.save(model.state_dict(), os.path.join(pathm, "iremmodel{}.pt".format(i)))
        #list(model.parameters())
        #print("\n____________________")
        #print(model.state_dict())
        validate(validationloss, accuracy, validation_generator, valFile, valaccFile, lim, lrFile, pathm, i, modeltype)
    torch.save(model.state_dict(), os.path.join(pathm, "Finaliremmodel{}.pt".format(i)))


def validate(validationloss, accuracy, validation_generator, valFile, valaccFile, lim, lrFile, pathm, i, modeltype):
    jI = 0
    totalBatches = 0
    validation_losses = []


    if modeltype=='DualNorm_Unet':
        model = DualNorm_Unet(n_channels=3, n_classes=1).to(device)

    model.load_state_dict(torch.load(os.path.join(pathm, "iremmodel{}.pt".format(i))))
    model.eval()
    with torch.no_grad():
        val_losses = []
        for valim, valmas in validation_generator:
            #model.eval()
            images=valim.to(device)
            masks=valmas.to(device)
            outputs=model(images)
            if validationloss == 'BCEWithLogitsLoss':
                loss=nn.BCEWithLogitsLoss() #loss = nn.BCELoss()
                # Convert the target tensor to a single-channel mask
                #masks = masks[:, 0:1, :, :]

                output = loss(outputs, masks)
            val_losses.append(output.item())
            batchLoad = len(masks)*lim*lim
            totalBatches = totalBatches + batchLoad
            if accuracy == 'Jaccard':
                thisJac = Jaccard(torch.reshape(masks,(batchLoad,1)),torch.reshape(outputs,(batchLoad,1)))*batchLoad
                jI = jI+thisJac.data[0]

    dn=jI/totalBatches
    dni=dn.item()
    validation_loss = np.mean(val_losses)
    validation_losses.append(validation_loss)
    valFile.write(str(validation_losses[0])+"\n")
    valaccFile.write(str(dni)+"\n")
    print("Validation Jaccard:",dni)
    print(f"Validation Jaccard: {dni:.2f}%")
    lrFile.write("Validation loss:"+str(validation_losses[0])+"\n")
    lrFile.write("Validation accuracy:"+str(dni)+"\n")

# %%
import numpy as np
import matplotlib.pyplot as plt
from F5_JACCARD import Jaccard

from F11_SEGPLOTT import segplot
#from F23_DULANORM_UNET_V3 import DualNorm_Unet



dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device(dev)

def test_model(test_generator, lim, testFile, testaccFile, i, modeltype, pathm, trMeanR, trMeanG, trMeanB):


    if modeltype=='DualNorm_Unet':
      net = DualNorm_Unet(n_channels=3, n_classes=1).to(device)



    net.load_state_dict(torch.load(os.path.join(pathm, "Finaliremmodel{}.pt".format(i))))

    jI = 0
    totalBatches = 0
    test_losses = []
    net.eval()
    with torch.no_grad():
        t_losses = []
        t=0
        for testim, testmas in test_generator:
            images=testim.to(device)
            masks=testmas.to(device)
            outputs = net(images)
            if t==0:
                fig=plt.figure()
                axes=[]
                fimage=images[0].permute(1, 2, 0)
                fimage[:,:,0]=(images[0][0,:,:])
                fimage[:,:,1]=(images[0][1,:,:])
                fimage[:,:,2]=(images[0][2,:,:])
                fimage=fimage.cpu().numpy()
                axes.append(fig.add_subplot(1, 2, 1))
                foutput=outputs[0].permute(1, 2, 0)
                foutput=foutput.cpu().numpy()

                print("=================================================================================\n\n")
                plt.imshow(np.squeeze(foutput, axis=2),  cmap='gray')
                subplot_title=("Test Predicted Mask")
                axes[-1].set_title(subplot_title)
                axes.append(fig.add_subplot(1, 2, 2))
                fmask=masks[0].permute(1, 2, 0)
                fmask=fmask.cpu().numpy()
                plt.imshow(np.squeeze(fmask, axis=2),  cmap='gray')


                plt.imshow(fmask, cmap='gray')

                subplot_title=("Ground Truth Mask")
                axes[-1].set_title(subplot_title)
                n_curve = 'mask_comparison.png'
                plt.savefig(os.path.join(pathm, n_curve))
                plt.show()
                segplot(pathm, lim, fimage, foutput, fmask,  trMeanR, trMeanG, trMeanB)
            losst=nn.BCEWithLogitsLoss()  #losst = nn.BCELoss()


            output = losst(outputs, masks)
            t_losses.append(output.item())
            batchLoad = len(masks)*lim*lim
            totalBatches = totalBatches + batchLoad
            thisJac = Jaccard(torch.reshape(masks,(batchLoad,1)),torch.reshape(outputs,(batchLoad,1)))*batchLoad
            jI = jI+thisJac.data[0]
            #jI = jI+thisJac.item()
            t +=1

    dn=jI/totalBatches
    dni=dn.item()
    test_loss = np.mean(t_losses)
    test_losses.append(test_loss)
    testFile.write(str(test_losses[0])+"\n")
    testaccFile.write(str(dni)+"\n")
    print("======================================TEST JACCARD===============================")
    print("Test Jaccard:",dni)
    print(f"Test Jaccard: {dni:.2f}% | Test losses: {test_loss:.2f}% ")
    print("---------------------------------------------------------------------------------")

# %%
from __future__ import print_function
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
#import numpy as np
import datetime
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
from F3_DATASET import satellitedata
#from F4_TRAIN import train_model
from F6_CROSSVAL import CrossVal
#from F7_TEST import test_model
#from F7_TEST2 import test_model
from F8_IMAGES import get_images
#from F23_DULANORM_UNET import DualNorm_Unet
#from F23_DULANORM_UNET_V1 import DualNorm_Unet
import ssl
ssl._create_default_https_context = ssl._create_unverified_context



##############################################################################
if __name__ == '__main__':

    if (torch.cuda.is_available()):
        print(torch.cuda.get_device_name(0))

    bg=datetime.datetime.now()
    bgh=bg.hour
    bgm=bg.minute


    dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    # Uncommented the cpu device
    #dev = torch.device("cpu")
    device = torch.device(dev)

    for i in range(0,2):
        data_folder = os.path.join("/content/drive/MyDrive/UNET_ARCHITECTURE/experiments")
        file_to_open = os.path.join(data_folder, "model{}.txt".format(i))
        with open(file_to_open) as f:
            #lines = f.readlines()
            lines = [line.rstrip() for line in f]
        trainSetSize=int(lines[0])
        fno = int(lines[1])
        fsiz = int(lines[2])
        valRatio = float(lines[3])
        miniBatchSize = int(lines[4])
        n_epochs = int(lines[5])
        learnRate = float(lines[6])
        optimizerType=str(lines[7])
        trainloss=str(lines[8])
        validationloss=str(lines[9])
        accuracy=str(lines[10])
        initialization=str(lines[11])
        step_size=int(lines[12])
        gamma=float(lines[13])
        lim=int(lines[14])
        modeltype=str(lines[15])
        chindex=str(lines[16])
        transfertype=str(lines[17])

        tsind, trind,vlind = CrossVal(trainSetSize,fno,fsiz)
        input_images, target_masks, trMeanR, trMeanG, trMeanB = get_images(trainSetSize, fno, fsiz, tsind, trind, vlind, chindex)

        params = {'batch_size': miniBatchSize, 'shuffle': False}

        training_set = satellitedata(input_images[trind], target_masks[trind])
        training_generator = DataLoader(training_set, **params)

        validation_set = satellitedata(input_images[vlind], target_masks[vlind])
        validation_generator = DataLoader(validation_set, **params)

        test_set = satellitedata(input_images[tsind], target_masks[tsind])
        test_generator = DataLoader(test_set, **params)


        if modeltype=='DualNorm_Unet':
            model = DualNorm_Unet(n_channels=3, n_classes=1).to(device)


###############################################################################
        def init_weights(m):
            if initialization == 'xavier_uniform_':
                if isinstance(m, nn.Conv2d):
                    torch.nn.init.xavier_uniform_(m.weight)
                    if m.bias is not None:
                        torch.nn.init.zeros_(m.bias)

            if initialization == 'xavier_normal_':
                if isinstance(m, nn.Conv2d):
                    torch.nn.init.xavier_normal_(m.weight)
                    if m.bias is not None:
                        torch.nn.init.zeros_(m.bias)

            if initialization == 'kaiming_uniform_':
                if isinstance(m, nn.Conv2d):
                    torch.nn.init.kaiming_uniform_(m.weight)
                    if m.bias is not None:
                        torch.nn.init.zeros_(m.bias)

            if initialization == 'kaiming_normal_':
                if isinstance(m, nn.Conv2d):
                    torch.nn.init.kaiming_normal_(m.weight)
                    if m.bias is not None:
                        torch.nn.init.zeros_(m.bias)
###############################################################################
        #model.apply(init_weights)

        if transfertype=='yestr':
            model.load_state_dict(torch.load(os.path.join(data_folder, "2022_8_15_11_11.pt")))
        elif transfertype=='notr':
            model.apply(init_weights)

        if optimizerType =='Adam':
            optim = torch.optim.Adam(model.parameters(),learnRate)
        elif optimizerType =='SGD':
            optim = torch.optim.SGD(model.parameters(),learnRate)
        elif optimizerType =='AdamW':
            optim = torch.optim.AdamW(model.parameters(),learnRate)

        scheduler = StepLR(optim, step_size, gamma)

        d=datetime.datetime.now()
        pathm = os.path.join(data_folder, "{}_{}_{}_{}_{}_model{}".format(d.year, d.month, d.day, d.hour, d.minute, i))
        os.mkdir(pathm)

        os.path.join(pathm, "lrFile.txt")
        lrFile = open("lrFile.txt","w")
        os.path.join(pathm, "trainaccFile.txt")
        trainaccFile = open("trainaccFile.txt","w")
        os.path.join(pathm, "valaccFile.txt")
        valaccFile = open("valaccFile.txt","w")
        os.path.join(pathm, "trainepochFile.txt")
        trainepochFile = open("trainepochFile.txt","w")
        os.path.join(pathm, "trainFile.txt")
        trainFile = open("trainFile.txt","w")
        os.path.join(pathm, "valFile.txt")
        valFile = open("valFile.txt","w")
        train_model(n_epochs, trainloss, validationloss, accuracy, model, scheduler, lrFile, training_generator, optim, lim, trainFile, trainaccFile, trainepochFile, validation_generator, valFile, valaccFile, pathm, i, modeltype)
        trainFile.close()
        valFile.close()
        trainaccFile.close()
        valaccFile.close()
        trainepochFile.close()
        lrFile.close()


        os.path.join(pathm, "testaccFile.txt")
        testaccFile = open("testaccFile.txt","w")
        os.path.join(pathm, "testFile.txt")
        testFile = open("testFile.txt","w")
        test_model(test_generator, lim, testFile, testaccFile, i, modeltype, pathm, trMeanR, trMeanG, trMeanB)
        testFile.close()
        testaccFile.close()

        x=[]
        with open("trainFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                x.append(float(l))

        y=[]
        with open("valFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                y.append(float(l))

        tt=[]
        with open("testFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                tt.append(float(l))

        z=[]
        with open("lrFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                z.append(l)

        xx=[]
        with open("trainaccFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                xx.append(float(l))

        yy=[]
        with open("valaccFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                yy.append(float(l))

        ta=[]
        with open("testaccFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                ta.append(float(l))

        e1=[]
        with open("trainepochFile.txt") as f:
            lines = f.readlines()
            for l in lines:
                e1.append(float(l))


        def logfile():
            global total_train_time
            a=datetime.datetime.now()
            myfile=os.path.join(pathm, "{}_{}_{}_{}_{}.txt".format(a.year, a.month, a.day, a.hour, a.minute))
            LogFile = open(myfile,"w")
            LogFile.write("Date:"+str(datetime.date.today())+"\n")
            LogFile.write("Ending Time:"+str(a.hour)+":"+str(a.minute)+"\n")
            LogFile.write("Starting Time:"+str(bgh)+":"+str(bgm)+"\n")
            LogFile.write("Total Training Time in seconds: "+str(total_train_time)+"\n")
            LogFile.write("Data set size:"+str(trainSetSize)+"\n")
            LogFile.write("Fold number:"+str(fno)+"\n")
            LogFile.write("Fold number:"+str(fsiz)+"\n")
            LogFile.write("Number of validation images:"+str(len(vlind))+"\n")
            LogFile.write("Number of training images:"+str(len(trind))+"\n")
            LogFile.write("Mini batch size:"+str(miniBatchSize)+"\n")
            LogFile.write("Type of initialization:"+initialization+"\n")
            LogFile.write("Test accuracy:"+str(ta)+"\n")
            LogFile.write("Learning rate:"+str(learnRate)+"\n")
            LogFile.write("Model version:"+str(modeltype)+"\n")
            LogFile.write("Optimizer type:"+optimizerType+"\n")
            LogFile.write("Total number of epochs:"+str(n_epochs)+"\n")
            LogFile.write("Training loss function:"+str(trainloss)+"\n")
            LogFile.write("Validation loss function:"+str(validationloss)+"\n")
            LogFile.write("Accuracy function:"+str(accuracy)+"\n")
            LogFile.write("Channel index:"+str(chindex)+"\n")
            LogFile.write("Transfer:"+str(transfertype)+"\n")
            LogFile.write("Model Summary:"+"\n"+str(model)+"\n")
            for i in range(len(z)):
                LogFile.write(str(z[i]))
            LogFile.close()

        logfile()


        print("============================LARNING CURVES=======================================\n")

        plt.plot(x,"k-", label="Train Loss")
        plt.plot(y,"r--", label="Validation Loss")
        plt.title('Learning Curves')
        plt.legend(loc="upper left")
        l_curve = 'learning_curves.png'
        plt.savefig(os.path.join(pathm, l_curve))
        plt.show()
        print("\n\n")

        print("==========================ACCURACY CURVES=======================================\n")

        plt.plot(xx, "k-", label="Train Accuracy")
        plt.plot(yy, "r--", label="Validation Accuracy")
        plt.title('Accuracy Curves')
        plt.legend(loc="upper left")
        a_curve = 'accuracy_curves.png'
        plt.savefig(os.path.join(pathm, a_curve))
        plt.show()

        print("\n\n")
        # print("Memory allocated before model {}".format(i),torch.cuda.memory_allocated(device=torch.device('cpu')))
        # #del model
        # #torch.cuda.empty_cache()
        # print("Memory allocated after model {}".format(i),torch.cuda.memory_allocated(device=torch.device('cpu')))

        # print("Memory allocated before model {}".format(i),torch.cuda.memory_allocated())
        # # del model
        # # torch.cuda.empty_cache()
        # # print("Memory allocated after model {}".format(i),torch.cuda.memory_allocated())

        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print("Device:", device)

        print("Memory allocated before model:", torch.cuda.memory_allocated(device=device))
        # del model
        # torch.cuda.empty_cache()
        print("Memory allocated after model:", torch.cuda.memory_allocated(device=device))

        print("Memory allocated before model:", torch.cuda.memory_allocated())
# Out:
# Tesla T4
# Original image size: (1778, 224, 224, 3) Original target mask size: (1778, 224, 224)
# ===============================================================================
#
# Reshaped image size: (1778, 3, 224, 224) Reshaped mask size: (1778, 1, 224, 224)
# ===============================================================================
#
#
# image size torch.Size([1778, 3, 224, 224]) mask size torch.Size([1778, 1, 224, 224])
# type image <class 'torch.Tensor'> type mask <class 'torch.Tensor'>
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0 LR: [0.001]
# Total training time: 675.41 seconds
# =================================================================================
# Training Jaccard: 0.6192628145217896  (epoch: 0 ) Training Locess:  0.4417680741140717
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.7367534637451172
# Validation Jaccard: 0.74%
# Epoch: 1 LR: [0.001]
# Total training time: 707.67 seconds
# =================================================================================
# Training Jaccard: 0.8276117444038391  (epoch: 1 ) Training Locess:  0.37664900131915746
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8800075650215149
# Validation Jaccard: 0.88%
# Epoch: 2 LR: [0.001]
# Total training time: 739.58 seconds
# =================================================================================
# Training Jaccard: 0.9089618921279907  (epoch: 2 ) Training Locess:  0.3533345904005201
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9380238056182861
# Validation Jaccard: 0.94%
# Epoch: 3 LR: [0.001]
# Total training time: 771.74 seconds
# =================================================================================
# Training Jaccard: 0.9396141171455383  (epoch: 3 ) Training Locess:  0.34493174050983627
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.956614077091217
# Validation Jaccard: 0.96%
# Epoch: 4 LR: [0.001]
# Total training time: 803.93 seconds
# =================================================================================
# Training Jaccard: 0.9541826844215393  (epoch: 4 ) Training Locess:  0.3409077270250571
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9657941460609436
# Validation Jaccard: 0.97%
# Epoch: 5 LR: [0.001]
# Total training time: 835.94 seconds
# =================================================================================
# Training Jaccard: 0.9621904492378235  (epoch: 5 ) Training Locess:  0.33870929401171834
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9684876203536987
# Validation Jaccard: 0.97%
# Epoch: 6 LR: [0.001]
# Total training time: 868.01 seconds
# =================================================================================
# Training Jaccard: 0.9668449759483337  (epoch: 6 ) Training Locess:  0.3374355682416966
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9723032116889954
# Validation Jaccard: 0.97%
# Epoch: 7 LR: [0.001]
# Total training time: 900.06 seconds
# =================================================================================
# Training Jaccard: 0.969654381275177  (epoch: 7 ) Training Locess:  0.3366517648100853
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9733997583389282
# Validation Jaccard: 0.97%
# Epoch: 8 LR: [0.001]
# Total training time: 932.11 seconds
# =================================================================================
# Training Jaccard: 0.971680223941803  (epoch: 8 ) Training Locess:  0.33610735363081884
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9753550291061401
# Validation Jaccard: 0.98%
# Epoch: 9 LR: [0.0009000000000000001]
# Total training time: 964.36 seconds
# =================================================================================
# Training Jaccard: 0.9730501770973206  (epoch: 9 ) Training Locess:  0.335742239105074
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9773277640342712
# Validation Jaccard: 0.98%
# Epoch: 10 LR: [0.0009000000000000001]
# Total training time: 996.39 seconds
# =================================================================================
# Training Jaccard: 0.9739100337028503  (epoch: 10 ) Training Locess:  0.3355051741788262
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9776430726051331
# Validation Jaccard: 0.98%
# Epoch: 11 LR: [0.0009000000000000001]
# Total training time: 1028.41 seconds
# =================================================================================
# Training Jaccard: 0.9748221635818481  (epoch: 11 ) Training Locess:  0.33528373076727513
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9791083335876465
# Validation Jaccard: 0.98%
# Epoch: 12 LR: [0.0009000000000000001]
# Total training time: 1060.51 seconds
# =================================================================================
# Training Jaccard: 0.975407600402832  (epoch: 12 ) Training Locess:  0.335115000997719
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9796422123908997
# Validation Jaccard: 0.98%
# Epoch: 13 LR: [0.0009000000000000001]
# Total training time: 1092.57 seconds
# =================================================================================
# Training Jaccard: 0.9753845930099487  (epoch: 13 ) Training Locess:  0.33510363337240723
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9794339537620544
# Validation Jaccard: 0.98%
# Epoch: 14 LR: [0.0009000000000000001]
# Total training time: 1124.98 seconds
# =================================================================================
# Training Jaccard: 0.9761841893196106  (epoch: 14 ) Training Locess:  0.33492657934364517
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9802109003067017
# Validation Jaccard: 0.98%
# Epoch: 15 LR: [0.0009000000000000001]
# Total training time: 1157.03 seconds
# =================================================================================
# Training Jaccard: 0.9765925407409668  (epoch: 15 ) Training Locess:  0.33481451476875107
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9806225895881653
# Validation Jaccard: 0.98%
# Epoch: 16 LR: [0.0009000000000000001]
# Total training time: 1189.05 seconds
# =================================================================================
# Training Jaccard: 0.9768804907798767  (epoch: 16 ) Training Locess:  0.334736904031352
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.98091059923172
# Validation Jaccard: 0.98%
# Epoch: 17 LR: [0.0009000000000000001]
# Total training time: 1221.32 seconds
# =================================================================================
# Training Jaccard: 0.9771173000335693  (epoch: 17 ) Training Locess:  0.33467253572062444
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9811516404151917
# Validation Jaccard: 0.98%
# Epoch: 18 LR: [0.0009000000000000001]
# Total training time: 1253.32 seconds
# =================================================================================
# Training Jaccard: 0.9773150682449341  (epoch: 18 ) Training Locess:  0.33461873154891164
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9813390970230103
# Validation Jaccard: 0.98%
# Epoch: 19 LR: [0.0008100000000000001]
# Total training time: 1285.46 seconds
# =================================================================================
# Training Jaccard: 0.9774779081344604  (epoch: 19 ) Training Locess:  0.33457474606601817
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.981519341468811
# Validation Jaccard: 0.98%
# Epoch: 20 LR: [0.0008100000000000001]
# Total training time: 1317.54 seconds
# =================================================================================
# Training Jaccard: 0.9776104092597961  (epoch: 20 ) Training Locess:  0.33453888995082753
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9816384315490723
# Validation Jaccard: 0.98%
# Epoch: 21 LR: [0.0008100000000000001]
# Total training time: 1349.64 seconds
# =================================================================================
# Training Jaccard: 0.9777257442474365  (epoch: 21 ) Training Locess:  0.3345070857750742
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.981744110584259
# Validation Jaccard: 0.98%
# Epoch: 22 LR: [0.0008100000000000001]
# Total training time: 1381.91 seconds
# =================================================================================
# Training Jaccard: 0.9778282642364502  (epoch: 22 ) Training Locess:  0.3344787657260895
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9818254113197327
# Validation Jaccard: 0.98%
# Epoch: 23 LR: [0.0008100000000000001]
# Total training time: 1414.00 seconds
# =================================================================================
# Training Jaccard: 0.9779195189476013  (epoch: 23 ) Training Locess:  0.3344536772684047
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9819088578224182
# Validation Jaccard: 0.98%
# Epoch: 24 LR: [0.0008100000000000001]
# Total training time: 1446.14 seconds
# =================================================================================
# Training Jaccard: 0.9780003428459167  (epoch: 24 ) Training Locess:  0.3344309965246602
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9819872975349426
# Validation Jaccard: 0.98%
# Epoch: 25 LR: [0.0008100000000000001]
# Total training time: 1478.42 seconds
# =================================================================================
# Training Jaccard: 0.9780746102333069  (epoch: 25 ) Training Locess:  0.33441042429522466
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9820601344108582
# Validation Jaccard: 0.98%
# Epoch: 26 LR: [0.0008100000000000001]
# Total training time: 1510.47 seconds
# =================================================================================
# Training Jaccard: 0.978141188621521  (epoch: 26 ) Training Locess:  0.3343913955123801
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9821191430091858
# Validation Jaccard: 0.98%
# Epoch: 27 LR: [0.0008100000000000001]
# Total training time: 1542.56 seconds
# =================================================================================
# Training Jaccard: 0.9782022833824158  (epoch: 27 ) Training Locess:  0.3343739576245609
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9821783304214478
# Validation Jaccard: 0.98%
# Epoch: 28 LR: [0.0008100000000000001]
# Total training time: 1574.61 seconds
# =================================================================================
# Training Jaccard: 0.9782561659812927  (epoch: 28 ) Training Locess:  0.3343579757370447
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9822298288345337
# Validation Jaccard: 0.98%
# Epoch: 29 LR: [0.000729]
# Total training time: 1606.73 seconds
# =================================================================================
# Training Jaccard: 0.9783066511154175  (epoch: 29 ) Training Locess:  0.3343426393050897
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9822955131530762
# Validation Jaccard: 0.98%
# Epoch: 30 LR: [0.000729]
# Total training time: 1638.79 seconds
# =================================================================================
# Training Jaccard: 0.978341281414032  (epoch: 30 ) Training Locess:  0.33432930198154953
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9823426008224487
# Validation Jaccard: 0.98%
# Epoch: 31 LR: [0.000729]
# Total training time: 1670.83 seconds
# =================================================================================
# Training Jaccard: 0.9783726930618286  (epoch: 31 ) Training Locess:  0.33431458747700643
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.982410728931427
# Validation Jaccard: 0.98%
# Epoch: 32 LR: [0.000729]
# Total training time: 1702.87 seconds
# =================================================================================
# Training Jaccard: 0.9783823490142822  (epoch: 32 ) Training Locess:  0.3342998223869424
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9823536276817322
# Validation Jaccard: 0.98%
# Epoch: 33 LR: [0.000729]
# Total training time: 1735.15 seconds
# =================================================================================
# Training Jaccard: 0.9781756401062012  (epoch: 33 ) Training Locess:  0.3343369313760808
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9821250438690186
# Validation Jaccard: 0.98%
# Epoch: 34 LR: [0.000729]
# Total training time: 1767.28 seconds
# =================================================================================
# Training Jaccard: 0.9784207344055176  (epoch: 34 ) Training Locess:  0.3343123362252587
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9824049472808838
# Validation Jaccard: 0.98%
# Epoch: 35 LR: [0.000729]
# Total training time: 1799.32 seconds
# =================================================================================
# Training Jaccard: 0.9784775376319885  (epoch: 35 ) Training Locess:  0.3342916855686589
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9824475646018982
# Validation Jaccard: 0.98%
# Epoch: 36 LR: [0.000729]
# Total training time: 1831.61 seconds
# =================================================================================
# Training Jaccard: 0.9785118103027344  (epoch: 36 ) Training Locess:  0.33427569152493225
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.982496440410614
# Validation Jaccard: 0.98%
# Epoch: 37 LR: [0.000729]
# Total training time: 1863.70 seconds
# =================================================================================
# Training Jaccard: 0.9785302877426147  (epoch: 37 ) Training Locess:  0.3342596602283026
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9825536608695984
# Validation Jaccard: 0.98%
# Epoch: 38 LR: [0.000729]
# Total training time: 1895.78 seconds
# =================================================================================
# Training Jaccard: 0.9781414866447449  (epoch: 38 ) Training Locess:  0.3343393979103942
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9824862480163574
# Validation Jaccard: 0.98%
# Epoch: 39 LR: [0.0006561000000000001]
# Total training time: 1928.18 seconds
# =================================================================================
# Training Jaccard: 0.978531002998352  (epoch: 39 ) Training Locess:  0.33429021623573807
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9825730919837952
# Validation Jaccard: 0.98%
# Epoch: 40 LR: [0.0006561000000000001]
# Total training time: 1960.26 seconds
# =================================================================================
# Training Jaccard: 0.9785676598548889  (epoch: 40 ) Training Locess:  0.33427478608332184
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9825853109359741
# Validation Jaccard: 0.98%
# Epoch: 41 LR: [0.0006561000000000001]
# Total training time: 1992.46 seconds
# =================================================================================
# Training Jaccard: 0.9785951375961304  (epoch: 41 ) Training Locess:  0.334260602922816
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9826049208641052
# Validation Jaccard: 0.98%
# Epoch: 42 LR: [0.0006561000000000001]
# Total training time: 2024.52 seconds
# =================================================================================
# Training Jaccard: 0.97861647605896  (epoch: 42 ) Training Locess:  0.33425046856466095
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9826305508613586
# Validation Jaccard: 0.98%
# Epoch: 43 LR: [0.0006561000000000001]
# Total training time: 2056.56 seconds
# =================================================================================
# Training Jaccard: 0.9786331057548523  (epoch: 43 ) Training Locess:  0.33424285760051325
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9826430082321167
# Validation Jaccard: 0.98%
# Epoch: 44 LR: [0.0006561000000000001]
# Total training time: 2088.80 seconds
# =================================================================================
# Training Jaccard: 0.9786481261253357  (epoch: 44 ) Training Locess:  0.33423730142806707
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9826704263687134
# Validation Jaccard: 0.98%
# Epoch: 45 LR: [0.0006561000000000001]
# Total training time: 2120.84 seconds
# =================================================================================
# Training Jaccard: 0.9786509275436401  (epoch: 45 ) Training Locess:  0.3342152257498942
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9827017188072205
# Validation Jaccard: 0.98%
# Epoch: 46 LR: [0.0006561000000000001]
# Total training time: 2152.94 seconds
# =================================================================================
# Training Jaccard: 0.9785841107368469  (epoch: 46 ) Training Locess:  0.33418239653110504
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9826640486717224
# Validation Jaccard: 0.98%
# Epoch: 47 LR: [0.0006561000000000001]
# Total training time: 2185.01 seconds
# =================================================================================
# Training Jaccard: 0.9786186218261719  (epoch: 47 ) Training Locess:  0.3342304065039283
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9825736284255981
# Validation Jaccard: 0.98%
# Epoch: 48 LR: [0.0006561000000000001]
# Total training time: 2217.10 seconds
# =================================================================================
# Training Jaccard: 0.9782306551933289  (epoch: 48 ) Training Locess:  0.3340696578747348
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9826103448867798
# Validation Jaccard: 0.98%
# Epoch: 49 LR: [0.00059049]
# Total training time: 2249.17 seconds
# =================================================================================
# Training Jaccard: 0.97864830493927  (epoch: 49 ) Training Locess:  0.33417401345152603
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9824128150939941
# Validation Jaccard: 0.98%
# Epoch: 50 LR: [0.00059049]
# Total training time: 2281.23 seconds
# =================================================================================
# Training Jaccard: 0.9779652953147888  (epoch: 50 ) Training Locess:  0.33369522816256475
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9823623895645142
# Validation Jaccard: 0.98%
# Epoch: 51 LR: [0.00059049]
# Total training time: 2313.28 seconds
# =================================================================================
# Training Jaccard: 0.9793305397033691  (epoch: 51 ) Training Locess:  0.33232554597289937
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.98348069190979
# Validation Jaccard: 0.98%
# Epoch: 52 LR: [0.00059049]
# Total training time: 2345.55 seconds
# =================================================================================
# Training Jaccard: 0.9830825328826904  (epoch: 52 ) Training Locess:  0.3301916596920867
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9819405674934387
# Validation Jaccard: 0.98%
# Epoch: 53 LR: [0.00059049]
# Total training time: 2377.59 seconds
# =================================================================================
# Training Jaccard: 0.9799491763114929  (epoch: 53 ) Training Locess:  0.3312061883901295
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9871789216995239
# Validation Jaccard: 0.99%
# Epoch: 54 LR: [0.00059049]
# Total training time: 2409.61 seconds
# =================================================================================
# Training Jaccard: 0.9830769896507263  (epoch: 54 ) Training Locess:  0.32898412605649546
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9890495538711548
# Validation Jaccard: 0.99%
# Epoch: 55 LR: [0.00059049]
# Total training time: 2441.81 seconds
# =================================================================================
# Training Jaccard: 0.9859567880630493  (epoch: 55 ) Training Locess:  0.32766158996444
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9923684000968933
# Validation Jaccard: 0.99%
# Epoch: 56 LR: [0.00059049]
# Total training time: 2473.82 seconds
# =================================================================================
# Training Jaccard: 0.9879881739616394  (epoch: 56 ) Training Locess:  0.3268515216676812
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9930148720741272
# Validation Jaccard: 0.99%
# Epoch: 57 LR: [0.00059049]
# Total training time: 2505.80 seconds
# =================================================================================
# Training Jaccard: 0.9890989065170288  (epoch: 57 ) Training Locess:  0.326377130260593
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9916942715644836
# Validation Jaccard: 0.99%
# Epoch: 58 LR: [0.00059049]
# Total training time: 2537.87 seconds
# =================================================================================
# Training Jaccard: 0.9902189373970032  (epoch: 58 ) Training Locess:  0.32594738704593557
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9938158392906189
# Validation Jaccard: 0.99%
# Epoch: 59 LR: [0.000531441]
# Total training time: 2569.97 seconds
# =================================================================================
# Training Jaccard: 0.9903215169906616  (epoch: 59 ) Training Locess:  0.3259424226064431
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9910485744476318
# Validation Jaccard: 0.99%
# Epoch: 60 LR: [0.000531441]
# Total training time: 2602.28 seconds
# =================================================================================
# Training Jaccard: 0.9902023077011108  (epoch: 60 ) Training Locess:  0.32595277734492956
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.99395751953125
# Validation Jaccard: 0.99%
# Epoch: 61 LR: [0.000531441]
# Total training time: 2634.31 seconds
# =================================================================================
# Training Jaccard: 0.9911547899246216  (epoch: 61 ) Training Locess:  0.32557895544328186
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9925268292427063
# Validation Jaccard: 0.99%
# Epoch: 62 LR: [0.000531441]
# Total training time: 2666.33 seconds
# =================================================================================
# Training Jaccard: 0.9918525815010071  (epoch: 62 ) Training Locess:  0.32533385369338486
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9932902455329895
# Validation Jaccard: 0.99%
# Epoch: 63 LR: [0.000531441]
# Total training time: 2698.55 seconds
# =================================================================================
# Training Jaccard: 0.9918453693389893  (epoch: 63 ) Training Locess:  0.3253131802929075
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9935013055801392
# Validation Jaccard: 0.99%
# Epoch: 64 LR: [0.000531441]
# Total training time: 2730.59 seconds
# =================================================================================
# Training Jaccard: 0.9920365214347839  (epoch: 64 ) Training Locess:  0.32524648269540385
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9937208890914917
# Validation Jaccard: 0.99%
# Epoch: 65 LR: [0.000531441]
# Total training time: 2762.63 seconds
# =================================================================================
# Training Jaccard: 0.9925382733345032  (epoch: 65 ) Training Locess:  0.3250654845645553
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9943140745162964
# Validation Jaccard: 0.99%
# Epoch: 66 LR: [0.000531441]
# Total training time: 2794.65 seconds
# =================================================================================
# Training Jaccard: 0.9924163222312927  (epoch: 66 ) Training Locess:  0.3251003191659325
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9931826591491699
# Validation Jaccard: 0.99%
# Epoch: 67 LR: [0.000531441]
# Total training time: 2826.74 seconds
# =================================================================================
# Training Jaccard: 0.9927504062652588  (epoch: 67 ) Training Locess:  0.32498811224573537
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9945306181907654
# Validation Jaccard: 0.99%
# Epoch: 68 LR: [0.000531441]
# Total training time: 2859.19 seconds
# =================================================================================
# Training Jaccard: 0.9929459095001221  (epoch: 68 ) Training Locess:  0.3249043712490483
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9945751428604126
# Validation Jaccard: 0.99%
# Epoch: 69 LR: [0.0004782969]
# Total training time: 2891.26 seconds
# =================================================================================
# Training Jaccard: 0.9931787252426147  (epoch: 69 ) Training Locess:  0.3248151634868823
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9947363138198853
# Validation Jaccard: 0.99%
# Epoch: 70 LR: [0.0004782969]
# Total training time: 2923.32 seconds
# =================================================================================
# Training Jaccard: 0.9934601783752441  (epoch: 70 ) Training Locess:  0.32471317327336263
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9949185252189636
# Validation Jaccard: 0.99%
# Epoch: 71 LR: [0.0004782969]
# Total training time: 2955.50 seconds
# =================================================================================
# Training Jaccard: 0.9934905171394348  (epoch: 71 ) Training Locess:  0.3246948044551046
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9948583841323853
# Validation Jaccard: 0.99%
# Epoch: 72 LR: [0.0004782969]
# Total training time: 2987.55 seconds
# =================================================================================
# Training Jaccard: 0.9935536980628967  (epoch: 72 ) Training Locess:  0.32467350010809143
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.994955837726593
# Validation Jaccard: 0.99%
# Epoch: 73 LR: [0.0004782969]
# Total training time: 3019.57 seconds
# =================================================================================
# Training Jaccard: 0.9929823875427246  (epoch: 73 ) Training Locess:  0.3248713275319652
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9888690710067749
# Validation Jaccard: 0.99%
# Epoch: 74 LR: [0.0004782969]
# Total training time: 3051.86 seconds
# =================================================================================
# Training Jaccard: 0.9928234219551086  (epoch: 74 ) Training Locess:  0.3249142322885363
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9947519302368164
# Validation Jaccard: 0.99%
# Epoch: 75 LR: [0.0004782969]
# Total training time: 3083.99 seconds
# =================================================================================
# Training Jaccard: 0.9935507774353027  (epoch: 75 ) Training Locess:  0.32465351098462153
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9950264096260071
# Validation Jaccard: 1.00%
# Epoch: 76 LR: [0.0004782969]
# Total training time: 3116.09 seconds
# =================================================================================
# Training Jaccard: 0.9934945702552795  (epoch: 76 ) Training Locess:  0.32465864992455434
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9951355457305908
# Validation Jaccard: 1.00%
# Epoch: 77 LR: [0.0004782969]
# Total training time: 3148.15 seconds
# =================================================================================
# Training Jaccard: 0.9939069747924805  (epoch: 77 ) Training Locess:  0.32450159560692937
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9952371716499329
# Validation Jaccard: 1.00%
# Epoch: 78 LR: [0.0004782969]
# Total training time: 3180.12 seconds
# =================================================================================
# Training Jaccard: 0.9940334558486938  (epoch: 78 ) Training Locess:  0.32445033286747177
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9952498078346252
# Validation Jaccard: 1.00%
# Epoch: 79 LR: [0.00043046721]
# Total training time: 3212.18 seconds
# =================================================================================
# Training Jaccard: 0.9940190315246582  (epoch: 79 ) Training Locess:  0.32443938129826594
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9952406287193298
# Validation Jaccard: 1.00%
# Epoch: 80 LR: [0.00043046721]
# Total training time: 3244.23 seconds
# =================================================================================
# Training Jaccard: 0.9940382838249207  (epoch: 80 ) Training Locess:  0.3244313652578153
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9952908754348755
# Validation Jaccard: 1.00%
# Epoch: 81 LR: [0.00043046721]
# Total training time: 3276.27 seconds
# =================================================================================
# Training Jaccard: 0.9943061470985413  (epoch: 81 ) Training Locess:  0.324328761351736
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.995398223400116
# Validation Jaccard: 1.00%
# Epoch: 82 LR: [0.00043046721]
# Total training time: 3308.56 seconds
# =================================================================================
# Training Jaccard: 0.9943914413452148  (epoch: 82 ) Training Locess:  0.3242901830296767
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9953721761703491
# Validation Jaccard: 1.00%
# Epoch: 83 LR: [0.00043046721]
# Total training time: 3340.61 seconds
# =================================================================================
# Training Jaccard: 0.9944813847541809  (epoch: 83 ) Training Locess:  0.32425810082962636
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9954374432563782
# Validation Jaccard: 1.00%
# Epoch: 84 LR: [0.00043046721]
# Total training time: 3372.66 seconds
# =================================================================================
# Training Jaccard: 0.994295060634613  (epoch: 84 ) Training Locess:  0.3243285935176046
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9953486919403076
# Validation Jaccard: 1.00%
# Epoch: 85 LR: [0.00043046721]
# Total training time: 3404.70 seconds
# =================================================================================
# Training Jaccard: 0.9942918419837952  (epoch: 85 ) Training Locess:  0.3243189716809674
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.995338499546051
# Validation Jaccard: 1.00%
# Epoch: 86 LR: [0.00043046721]
# Total training time: 3436.72 seconds
# =================================================================================
# Training Jaccard: 0.9946098327636719  (epoch: 86 ) Training Locess:  0.3242047864355539
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9954891800880432
# Validation Jaccard: 1.00%
# Epoch: 87 LR: [0.00043046721]
# Total training time: 3468.94 seconds
# =================================================================================
# Training Jaccard: 0.994659960269928  (epoch: 87 ) Training Locess:  0.32418415617001684
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9954972267150879
# Validation Jaccard: 1.00%
# Epoch: 88 LR: [0.00043046721]
# Total training time: 3500.98 seconds
# =================================================================================
# Training Jaccard: 0.9946553111076355  (epoch: 88 ) Training Locess:  0.3241835875730765
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9955173134803772
# Validation Jaccard: 1.00%
# Epoch: 89 LR: [0.000387420489]
# Total training time: 3533.01 seconds
# =================================================================================
# Training Jaccard: 0.9947450160980225  (epoch: 89 ) Training Locess:  0.32414524649318893
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9954900741577148
# Validation Jaccard: 1.00%
# Epoch: 90 LR: [0.000387420489]
# Total training time: 3565.28 seconds
# =================================================================================
# Training Jaccard: 0.9949128031730652  (epoch: 90 ) Training Locess:  0.32408831268548965
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9955477714538574
# Validation Jaccard: 1.00%
# Epoch: 91 LR: [0.000387420489]
# Total training time: 3597.32 seconds
# =================================================================================
# Training Jaccard: 0.9950292110443115  (epoch: 91 ) Training Locess:  0.324041159529435
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9955618977546692
# Validation Jaccard: 1.00%
# Epoch: 92 LR: [0.000387420489]
# Total training time: 3629.40 seconds
# =================================================================================
# Training Jaccard: 0.9951081275939941  (epoch: 92 ) Training Locess:  0.32401162895717117
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9955934286117554
# Validation Jaccard: 1.00%
# Epoch: 93 LR: [0.000387420489]
# Total training time: 3661.63 seconds
# =================================================================================
# Training Jaccard: 0.9951788187026978  (epoch: 93 ) Training Locess:  0.3239835920302491
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956085681915283
# Validation Jaccard: 1.00%
# Epoch: 94 LR: [0.000387420489]
# Total training time: 3693.62 seconds
# =================================================================================
# Training Jaccard: 0.9951993823051453  (epoch: 94 ) Training Locess:  0.32397489759482834
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956269264221191
# Validation Jaccard: 1.00%
# Epoch: 95 LR: [0.000387420489]
# Total training time: 3725.65 seconds
# =================================================================================
# Training Jaccard: 0.9952452778816223  (epoch: 95 ) Training Locess:  0.32395680601659577
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956426620483398
# Validation Jaccard: 1.00%
# Epoch: 96 LR: [0.000387420489]
# Total training time: 3757.69 seconds
# =================================================================================
# Training Jaccard: 0.9952648878097534  (epoch: 96 ) Training Locess:  0.3239480190371212
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956486225128174
# Validation Jaccard: 1.00%
# Epoch: 97 LR: [0.000387420489]
# Total training time: 3789.68 seconds
# =================================================================================
# Training Jaccard: 0.9953011274337769  (epoch: 97 ) Training Locess:  0.32393403547374827
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956599473953247
# Validation Jaccard: 1.00%
# Epoch: 98 LR: [0.000387420489]
# Total training time: 3821.89 seconds
# =================================================================================
# Training Jaccard: 0.9953073859214783  (epoch: 98 ) Training Locess:  0.3239294412104707
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956594109535217
# Validation Jaccard: 1.00%
# Epoch: 99 LR: [0.0003486784401]
# Total training time: 3853.88 seconds
# =================================================================================
# Training Jaccard: 0.9953510165214539  (epoch: 99 ) Training Locess:  0.3239123734988664
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9956770539283752
# Validation Jaccard: 1.00%
# =================================================================================
# ===============================================================================
#
#
# image shape (224, 224, 3) output shape (224, 224, 1) groundtruth shape (224, 224, 1)
# 1.0
# ======================================TEST JACCARD===============================
# Test Jaccard: 0.995485246181488
# Test Jaccard: 1.00% | Test losses: 0.32%
# ---------------------------------------------------------------------------------
# ============================LARNING CURVES=======================================
# ==========================ACCURACY CURVES=======================================
# Device: cuda
# Memory allocated before model: 334054912
# Memory allocated after model: 334054912
# Memory allocated before model: 334054912
# Original image size: (1778, 224, 224, 3) Original target mask size: (1778, 224, 224)
# ===============================================================================
#
# Reshaped image size: (1778, 3, 224, 224) Reshaped mask size: (1778, 1, 224, 224)
# ===============================================================================
#
#
# image size torch.Size([1778, 3, 224, 224]) mask size torch.Size([1778, 1, 224, 224])
# type image <class 'torch.Tensor'> type mask <class 'torch.Tensor'>
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0 LR: [0.0001]
# Total training time: 3914.81 seconds
# =================================================================================
# Training Jaccard: 0.5431674718856812  (epoch: 0 ) Training Locess:  0.4798144588344975
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.5751628875732422
# Validation Jaccard: 0.58%
# Epoch: 1 LR: [0.0001]
# Total training time: 3947.08 seconds
# =================================================================================
# Training Jaccard: 0.5986176133155823  (epoch: 1 ) Training Locess:  0.46094403690413427
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.6077294945716858
# Validation Jaccard: 0.61%
# Epoch: 2 LR: [0.0001]
# Total training time: 3979.01 seconds
# =================================================================================
# Training Jaccard: 0.6199362874031067  (epoch: 2 ) Training Locess:  0.4538347783841585
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.6292901635169983
# Validation Jaccard: 0.63%
# Epoch: 3 LR: [0.0001]
# Total training time: 4011.44 seconds
# =================================================================================
# Training Jaccard: 0.6384707093238831  (epoch: 3 ) Training Locess:  0.447648144474155
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.6473698616027832
# Validation Jaccard: 0.65%
# Epoch: 4 LR: [0.0001]
# Total training time: 4043.55 seconds
# =================================================================================
# Training Jaccard: 0.6550856828689575  (epoch: 4 ) Training Locess:  0.44201264569633886
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.6591141819953918
# Validation Jaccard: 0.66%
# Epoch: 5 LR: [0.0001]
# Total training time: 4075.59 seconds
# =================================================================================
# Training Jaccard: 0.6711083054542542  (epoch: 5 ) Training Locess:  0.43654937963736684
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.6690108180046082
# Validation Jaccard: 0.67%
# Epoch: 6 LR: [0.0001]
# Total training time: 4107.74 seconds
# =================================================================================
# Training Jaccard: 0.6870473623275757  (epoch: 6 ) Training Locess:  0.4309501573443413
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.6824623346328735
# Validation Jaccard: 0.68%
# Epoch: 7 LR: [0.0001]
# Total training time: 4139.84 seconds
# =================================================================================
# Training Jaccard: 0.7040926814079285  (epoch: 7 ) Training Locess:  0.42436703804292175
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.704811155796051
# Validation Jaccard: 0.70%
# Epoch: 8 LR: [0.0001]
# Total training time: 4172.14 seconds
# =================================================================================
# Training Jaccard: 0.7153434157371521  (epoch: 8 ) Training Locess:  0.41332941894468506
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.7756332159042358
# Validation Jaccard: 0.78%
# Epoch: 9 LR: [9e-05]
# Total training time: 4204.19 seconds
# =================================================================================
# Training Jaccard: 0.7667359709739685  (epoch: 9 ) Training Locess:  0.39276372602111415
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8009331226348877
# Validation Jaccard: 0.80%
# Epoch: 10 LR: [9e-05]
# Total training time: 4236.29 seconds
# =================================================================================
# Training Jaccard: 0.7965928912162781  (epoch: 10 ) Training Locess:  0.3835907045163606
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8274360299110413
# Validation Jaccard: 0.83%
# Epoch: 11 LR: [9e-05]
# Total training time: 4268.58 seconds
# =================================================================================
# Training Jaccard: 0.8191034197807312  (epoch: 11 ) Training Locess:  0.3765040392938413
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8524603247642517
# Validation Jaccard: 0.85%
# Epoch: 12 LR: [9e-05]
# Total training time: 4300.60 seconds
# =================================================================================
# Training Jaccard: 0.8363996148109436  (epoch: 12 ) Training Locess:  0.37117441233835724
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8649166822433472
# Validation Jaccard: 0.86%
# Epoch: 13 LR: [9e-05]
# Total training time: 4332.65 seconds
# =================================================================================
# Training Jaccard: 0.8494115471839905  (epoch: 13 ) Training Locess:  0.367315584499585
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8632321357727051
# Validation Jaccard: 0.86%
# Epoch: 14 LR: [9e-05]
# Total training time: 4364.71 seconds
# =================================================================================
# Training Jaccard: 0.8627429604530334  (epoch: 14 ) Training Locess:  0.36312950598566157
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8630896210670471
# Validation Jaccard: 0.86%
# Epoch: 15 LR: [9e-05]
# Total training time: 4396.78 seconds
# =================================================================================
# Training Jaccard: 0.8739194273948669  (epoch: 15 ) Training Locess:  0.35976177532421916
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8679605722427368
# Validation Jaccard: 0.87%
# Epoch: 16 LR: [9e-05]
# Total training time: 4429.02 seconds
# =================================================================================
# Training Jaccard: 0.8836362361907959  (epoch: 16 ) Training Locess:  0.35680508456732096
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.8738765120506287
# Validation Jaccard: 0.87%
# Epoch: 17 LR: [9e-05]
# Total training time: 4461.08 seconds
# =================================================================================
# Training Jaccard: 0.8921801447868347  (epoch: 17 ) Training Locess:  0.3543484144304928
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9013137221336365
# Validation Jaccard: 0.90%
# Epoch: 18 LR: [9e-05]
# Total training time: 4493.12 seconds
# =================================================================================
# Training Jaccard: 0.9005124568939209  (epoch: 18 ) Training Locess:  0.3518725202271813
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9111328125
# Validation Jaccard: 0.91%
# Epoch: 19 LR: [8.1e-05]
# Total training time: 4525.16 seconds
# =================================================================================
# Training Jaccard: 0.9046699404716492  (epoch: 19 ) Training Locess:  0.3510251586374484
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9151071310043335
# Validation Jaccard: 0.92%
# Epoch: 20 LR: [8.1e-05]
# Total training time: 4557.21 seconds
# ...
# Training Jaccard: 0.9852038025856018  (epoch: 61 ) Training Locess:  0.3266788156409013
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9862655997276306
# Validation Jaccard: 0.99%
# Epoch: 62 LR: [5.314410000000002e-05]
# Total training time: 5905.79 seconds
# =================================================================================
# Training Jaccard: 0.985556960105896  (epoch: 62 ) Training Locess:  0.32658266001626063
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9862673878669739
# Validation Jaccard: 0.99%
# Epoch: 63 LR: [5.314410000000002e-05]
# Total training time: 5937.83 seconds
# =================================================================================
# Training Jaccard: 0.9858559370040894  (epoch: 63 ) Training Locess:  0.32652339731392105
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9869861006736755
# Validation Jaccard: 0.99%
# Epoch: 64 LR: [5.314410000000002e-05]
# Total training time: 5969.91 seconds
# =================================================================================
# Training Jaccard: 0.9861823320388794  (epoch: 64 ) Training Locess:  0.3264127828572926
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9870553612709045
# Validation Jaccard: 0.99%
# Epoch: 65 LR: [5.314410000000002e-05]
# Total training time: 6001.96 seconds
# =================================================================================
# Training Jaccard: 0.9865807890892029  (epoch: 65 ) Training Locess:  0.3262921493304403
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9873077869415283
# Validation Jaccard: 0.99%
# Epoch: 66 LR: [5.314410000000002e-05]
# Total training time: 6034.24 seconds
# =================================================================================
# Training Jaccard: 0.9869071841239929  (epoch: 66 ) Training Locess:  0.32619870689354447
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9876934885978699
# Validation Jaccard: 0.99%
# Epoch: 67 LR: [5.314410000000002e-05]
# Total training time: 6066.31 seconds
# =================================================================================
# Training Jaccard: 0.987227737903595  (epoch: 67 ) Training Locess:  0.32610659850271123
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.987896203994751
# Validation Jaccard: 0.99%
# Epoch: 68 LR: [5.314410000000002e-05]
# Total training time: 6098.34 seconds
# =================================================================================
# Training Jaccard: 0.9875292181968689  (epoch: 68 ) Training Locess:  0.3260210066249496
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9881575703620911
# Validation Jaccard: 0.99%
# Epoch: 69 LR: [4.782969000000002e-05]
# Total training time: 6130.58 seconds
# =================================================================================
# Training Jaccard: 0.9878113269805908  (epoch: 69 ) Training Locess:  0.3259411520863834
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9883902072906494
# Validation Jaccard: 0.99%
# Epoch: 70 LR: [4.782969000000002e-05]
# Total training time: 6162.62 seconds
# =================================================================================
# Training Jaccard: 0.988065779209137  (epoch: 70 ) Training Locess:  0.32586996806295293
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.988578200340271
# Validation Jaccard: 0.99%
# Epoch: 71 LR: [4.782969000000002e-05]
# Total training time: 6194.65 seconds
# =================================================================================
# Training Jaccard: 0.9883142709732056  (epoch: 71 ) Training Locess:  0.3257992663665822
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.988848865032196
# Validation Jaccard: 0.99%
# Epoch: 72 LR: [4.782969000000002e-05]
# Total training time: 6226.72 seconds
# =================================================================================
# Training Jaccard: 0.9885520339012146  (epoch: 72 ) Training Locess:  0.32573265739177404
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9889851212501526
# Validation Jaccard: 0.99%
# Epoch: 73 LR: [4.782969000000002e-05]
# Total training time: 6258.92 seconds
# =================================================================================
# Training Jaccard: 0.9887834787368774  (epoch: 73 ) Training Locess:  0.32566682327734797
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9892095923423767
# Validation Jaccard: 0.99%
# Epoch: 74 LR: [4.782969000000002e-05]
# Total training time: 6291.20 seconds
# =================================================================================
# Training Jaccard: 0.9890047907829285  (epoch: 74 ) Training Locess:  0.32560618535468455
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9892905950546265
# Validation Jaccard: 0.99%
# Epoch: 75 LR: [4.782969000000002e-05]
# Total training time: 6323.26 seconds
# =================================================================================
# Training Jaccard: 0.9892258644104004  (epoch: 75 ) Training Locess:  0.3255436016540778
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9895990490913391
# Validation Jaccard: 0.99%
# Epoch: 76 LR: [4.782969000000002e-05]
# Total training time: 6355.29 seconds
# =================================================================================
# Training Jaccard: 0.9894276857376099  (epoch: 76 ) Training Locess:  0.32549110917668594
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9894505143165588
# Validation Jaccard: 0.99%
# Epoch: 77 LR: [4.782969000000002e-05]
# Total training time: 6387.53 seconds
# =================================================================================
# Training Jaccard: 0.9859690070152283  (epoch: 77 ) Training Locess:  0.32682131034763234
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9751629829406738
# Validation Jaccard: 0.98%
# Epoch: 78 LR: [4.782969000000002e-05]
# Total training time: 6419.66 seconds
# =================================================================================
# Training Jaccard: 0.9862356185913086  (epoch: 78 ) Training Locess:  0.3267110378334397
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9903427958488464
# Validation Jaccard: 0.99%
# Epoch: 79 LR: [4.304672100000002e-05]
# Total training time: 6451.74 seconds
# =================================================================================
# Training Jaccard: 0.9893898963928223  (epoch: 79 ) Training Locess:  0.325551752197115
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9903692007064819
# Validation Jaccard: 0.99%
# Epoch: 80 LR: [4.304672100000002e-05]
# Total training time: 6484.01 seconds
# =================================================================================
# Training Jaccard: 0.9898324012756348  (epoch: 80 ) Training Locess:  0.3254070564320213
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9904285073280334
# Validation Jaccard: 0.99%
# Epoch: 81 LR: [4.304672100000002e-05]
# Total training time: 6516.03 seconds
# =================================================================================
# Training Jaccard: 0.9901278018951416  (epoch: 81 ) Training Locess:  0.3253122732827538
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9906027317047119
# Validation Jaccard: 0.99%
# Epoch: 82 LR: [4.304672100000002e-05]
# Total training time: 6548.15 seconds
# =================================================================================
# Training Jaccard: 0.9903504252433777  (epoch: 82 ) Training Locess:  0.3252449047408606
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9907736778259277
# Validation Jaccard: 0.99%
# Epoch: 83 LR: [4.304672100000002e-05]
# Total training time: 6580.17 seconds
# =================================================================================
# Training Jaccard: 0.9905427098274231  (epoch: 83 ) Training Locess:  0.3251875850715135
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9909412860870361
# Validation Jaccard: 0.99%
# Epoch: 84 LR: [4.304672100000002e-05]
# Total training time: 6612.20 seconds
# =================================================================================
# Training Jaccard: 0.990726113319397  (epoch: 84 ) Training Locess:  0.3251337950166903
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9911020994186401
# Validation Jaccard: 0.99%
# Epoch: 85 LR: [4.304672100000002e-05]
# Total training time: 6644.47 seconds
# =================================================================================
# Training Jaccard: 0.9908936619758606  (epoch: 85 ) Training Locess:  0.3250853023246715
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9912501573562622
# Validation Jaccard: 0.99%
# Epoch: 86 LR: [4.304672100000002e-05]
# Total training time: 6676.51 seconds
# =================================================================================
# Training Jaccard: 0.9910534024238586  (epoch: 86 ) Training Locess:  0.3250395353687437
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9914035797119141
# Validation Jaccard: 0.99%
# Epoch: 87 LR: [4.304672100000002e-05]
# Total training time: 6708.55 seconds
# =================================================================================
# Training Jaccard: 0.9912048578262329  (epoch: 87 ) Training Locess:  0.324996327491183
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9915438890457153
# Validation Jaccard: 0.99%
# Epoch: 88 LR: [4.304672100000002e-05]
# Total training time: 6740.69 seconds
# =================================================================================
# Training Jaccard: 0.9913510680198669  (epoch: 88 ) Training Locess:  0.3249548603045313
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.991679847240448
# Validation Jaccard: 0.99%
# Epoch: 89 LR: [3.874204890000002e-05]
# Total training time: 6772.73 seconds
# =================================================================================
# Training Jaccard: 0.991489827632904  (epoch: 89 ) Training Locess:  0.3249155090827691
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9917536377906799
# Validation Jaccard: 0.99%
# Epoch: 90 LR: [3.874204890000002e-05]
# Total training time: 6804.97 seconds
# =================================================================================
# Training Jaccard: 0.9916139245033264  (epoch: 90 ) Training Locess:  0.3248801768610352
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9918734431266785
# Validation Jaccard: 0.99%
# Epoch: 91 LR: [3.874204890000002e-05]
# Total training time: 6837.00 seconds
# =================================================================================
# Training Jaccard: 0.9917353987693787  (epoch: 91 ) Training Locess:  0.3248457700798386
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9919746518135071
# Validation Jaccard: 0.99%
# Epoch: 92 LR: [3.874204890000002e-05]
# Total training time: 6869.06 seconds
# =================================================================================
# Training Jaccard: 0.9918538928031921  (epoch: 92 ) Training Locess:  0.3248123208943166
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9920871257781982
# Validation Jaccard: 0.99%
# Epoch: 93 LR: [3.874204890000002e-05]
# Total training time: 6901.19 seconds
# =================================================================================
# Training Jaccard: 0.9919706583023071  (epoch: 93 ) Training Locess:  0.32477934070323644
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9921842217445374
# Validation Jaccard: 0.99%
# Epoch: 94 LR: [3.874204890000002e-05]
# Total training time: 6933.19 seconds
# =================================================================================
# Training Jaccard: 0.9920870065689087  (epoch: 94 ) Training Locess:  0.3247467997042756
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9922778010368347
# Validation Jaccard: 0.99%
# Epoch: 95 LR: [3.874204890000002e-05]
# Total training time: 6965.22 seconds
# =================================================================================
# Training Jaccard: 0.9922082424163818  (epoch: 95 ) Training Locess:  0.3247131356283238
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9923459887504578
# Validation Jaccard: 0.99%
# Epoch: 96 LR: [3.874204890000002e-05]
# Total training time: 6997.47 seconds
# =================================================================================
# Training Jaccard: 0.9923366904258728  (epoch: 96 ) Training Locess:  0.3246784763116586
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9924219250679016
# Validation Jaccard: 0.99%
# Epoch: 97 LR: [3.874204890000002e-05]
# Total training time: 7029.44 seconds
# =================================================================================
# Training Jaccard: 0.9924582242965698  (epoch: 97 ) Training Locess:  0.3246445373484963
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9924772381782532
# Validation Jaccard: 0.99%
# Epoch: 98 LR: [3.874204890000002e-05]
# Total training time: 7061.70 seconds
# =================================================================================
# Training Jaccard: 0.9925726652145386  (epoch: 98 ) Training Locess:  0.3246124712260146
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9925949573516846
# Validation Jaccard: 0.99%
# Epoch: 99 LR: [3.4867844010000016e-05]
# Total training time: 7093.89 seconds
# =================================================================================
# Training Jaccard: 0.9926797151565552  (epoch: 99 ) Training Locess:  0.3245821136393045
# ---------------------------------------------------------------------------------
#
# Validation Jaccard: 0.9926096200942993
# Validation Jaccard: 0.99%
# =================================================================================
# ===============================================================================
#
#
# image shape (224, 224, 3) output shape (224, 224, 1) groundtruth shape (224, 224, 1)
# 1.0
# ======================================TEST JACCARD===============================
# Test Jaccard: 0.9928948283195496
# Test Jaccard: 0.99% | Test losses: 0.33%
# ---------------------------------------------------------------------------------
# ============================LARNING CURVES=======================================
# ==========================ACCURACY CURVES=======================================
# Device: cuda
# Memory allocated before model: 334999552
# Memory allocated after model: 334999552
# Memory allocated before model: 334999552

# %%
#%%writefile /content/drive/MyDrive/UNET_ARCHITECTURE/plot_sample_test_images.py

"""
Contains functionality for creating plot images of our trained model.
"""
import os
import matplotlib.pyplot as plt


recent_experiment_folder_path = "/content/drive/MyDrive/UNET_ARCHITECTURE/experiments/"
items = os.listdir(recent_experiment_folder_path)
most_recent_item_model_1 = items[-1] # Print the Mose Recent Model_One
# #most_recent_item_model_0 = items[-2] # Print the second Mose Recent Model_Zero

# Plot images for experiment model one
def plot_image_grid_model_1():
  print("Segmentation, Test, and Ground Truth Images for experiment Model One (1) \n\n")

  folder_path = f"/content/drive/MyDrive/UNET_ARCHITECTURE/experiments/{most_recent_item_model_1}"

  # List of image filenames and their corresponding labels
  image_names = ['segmentation_image.png','test_image.png', 'test_image_B.png', 'test_image_G.png',
                'test_pred_mask.png', 'ground_truth_mask.png',
                'test_image.png']
  image_labels = ['Segmentation', 'Test Image', 'Test Image (Blue Channel)', 'Test Image (Green Channel)',
                  'Predicted Mask', 'Ground Truth Mask', 'Test Image']

  # Get the list of image file names in the folder that match the names in image_names
  image_files = [filename for filename in os.listdir(folder_path) if filename in image_names]

  # Create a grid of subplots dynamically based on the number of image files
  num_images = len(image_files)
  rows = 3
  cols = 3
  fig, axes = plt.subplots(rows, cols, figsize=(8, 8))

  # Iterate over the image files and plot them in the subplots with corresponding labels
  for i, ax in enumerate(axes.flat):
      if i < num_images:
          image_path = os.path.join(folder_path, image_files[i])
          image = plt.imread(image_path)
          ax.imshow(image)
          ax.set_title(image_labels[i])  # Set the corresponding label as the subplot title
          plt.title("Preview of the Segmentation, Test and ground Truth Image ")
          ax.axis('on')
      else:
          ax.axis('off')

  # Adjust spacing between subplots
  plt.tight_layout()

  # Display the grid of images
  plt.show()


# recent_experiment_folder_path = "/content/drive/MyDrive/UNET_ARCHITECTURE/experiments/"
# items = os.listdir(recent_experiment_folder_path)
# #most_recent_item = items[-1] # Print the Mose Recent Model_One
most_recent_item_model_0 = items[-2] # Print the second Mose Recent Model_Zero


# Plot images for experiment model one
def plot_image_grid_model_0():
  print("Segmentation, Test, and Ground Truth Images for experiment Model Zero (0) \n\n")

  folder_path = f"/content/drive/MyDrive/UNET_ARCHITECTURE/experiments/{most_recent_item_model_0}"

  # List of image filenames and their corresponding labels
  image_names = ['segmentation_image.png','test_image.png', 'test_image_B.png', 'test_image_G.png',
                'test_pred_mask.png', 'ground_truth_mask.png',
                'test_image.png']
  image_labels = ['Segmentation', 'Test Image', 'Test Image (Blue Channel)', 'Test Image (Green Channel)',
                  'Predicted Mask', 'Ground Truth Mask', 'Test Image']

  # Get the list of image file names in the folder that match the names in image_names
  image_files = [filename for filename in os.listdir(folder_path) if filename in image_names]

  # Create a grid of subplots dynamically based on the number of image files
  num_images = len(image_files)
  rows = 3
  cols = 3
  fig, axes = plt.subplots(rows, cols, figsize=(8, 8))

  # Iterate over the image files and plot them in the subplots with corresponding labels
  for i, ax in enumerate(axes.flat):
      if i < num_images:
          image_path = os.path.join(folder_path, image_files[i])
          image = plt.imread(image_path)
          ax.imshow(image)
          ax.set_title(image_labels[i])  # Set the corresponding label as the subplot title
          plt.title("Preview of the Segmentation, Test and ground Truth Image ")
          ax.axis('on')
      else:
          ax.axis('off')

  # Adjust spacing between subplots
  plt.tight_layout()

  # Display the grid of images
  plt.show()

# %%
plot_image_grid_model_0(), plot_image_grid_model_1()
# Out:
# Segmentation, Test, and Ground Truth Images for experiment Model Zero (0)
# Segmentation, Test, and Ground Truth Images for experiment Model One (1)
# (None, None)
